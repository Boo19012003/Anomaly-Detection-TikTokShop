# %%
import pandas as pd

df = pd.read_csv('tiktok_shop_products_updated.csv')

df.head()
# Out:
#             product_id                                              title  \
# 0  1731982884920395437          (MỞ BÁN) Áo cardigan Dáng Ngắn BYJANE-999
# 1  1732477576245380758  Có BIGSIZE. Áo bí 2 dây babydoll basic dáng rộ...
# 2  1732242929860511562  Áo Khoác Cardigan JUSTDUN 201 Nữ - Dáng Vừa, V...
# 3  1733056843041572154  Đồ bộ tole nữ tay dài quần dài , đồ bộ nữ mặc ...
# 4  1732295703259743988  Áo Phao Cổ Lông Trần Bông Dáng Vừa Cho Nữ Kiểu...
#
#                                                 link                category  \
# 0  https://www.tiktok.com/shop/vn/pdp/ao-cardigan...  Womenswear & Underwear
# 1  https://www.tiktok.com/shop/vn/pdp/ao-babydoll...  Womenswear & Underwear
# 2  https://www.tiktok.com/shop/vn/pdp/ao-khoac-ca...  Womenswear & Underwear
# 3  https://www.tiktok.com/shop/vn/pdp/%C4%91o-bo-...  Womenswear & Underwear
# 4  https://www.tiktok.com/shop/vn/pdp/ao-phao-co-...  Womenswear & Underwear
#
# ...

# %%
df_new = df.copy()
df_new['label_trend'] = df_new['label_trend'].str.extract(r"'label_trend': '([^']*)'")
df_new.head()
# Out:
#             product_id                                              title  \
# 0  1731982884920395437          (MỞ BÁN) Áo cardigan Dáng Ngắn BYJANE-999
# 1  1732477576245380758  Có BIGSIZE. Áo bí 2 dây babydoll basic dáng rộ...
# 2  1732242929860511562  Áo Khoác Cardigan JUSTDUN 201 Nữ - Dáng Vừa, V...
# 3  1733056843041572154  Đồ bộ tole nữ tay dài quần dài , đồ bộ nữ mặc ...
# 4  1732295703259743988  Áo Phao Cổ Lông Trần Bông Dáng Vừa Cho Nữ Kiểu...
#
#                                                 link                category  \
# 0  https://www.tiktok.com/shop/vn/pdp/ao-cardigan...  Womenswear & Underwear
# 1  https://www.tiktok.com/shop/vn/pdp/ao-babydoll...  Womenswear & Underwear
# 2  https://www.tiktok.com/shop/vn/pdp/ao-khoac-ca...  Womenswear & Underwear
# 3  https://www.tiktok.com/shop/vn/pdp/%C4%91o-bo-...  Womenswear & Underwear
# 4  https://www.tiktok.com/shop/vn/pdp/ao-phao-co-...  Womenswear & Underwear
#
# ...

# %%
df_new.to_csv('tiktok_shop_products_cleaned.csv', index=False)
